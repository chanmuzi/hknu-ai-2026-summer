# %% [markdown]
# # 3차시 ― 파이썬 기초 ① · 변수와 자료형
#
# > 1차시에서 Google Colab에 접속해 코드 셀을 실행해 보았습니다. 이번 노트북부터는 **파이썬 문법을 처음부터** 익힙니다. 프로그래밍 경험이 없어도 따라올 수 있도록, **개념 설명 → 코드 실행 → 연습문제** 순서로 구성했습니다.
# >
# > **실행 방법**: 코드 셀을 클릭하고 `Shift + Enter`. 위에서 아래로 순서대로 실행하세요. 앞 셀의 변수를 뒤 셀에서 사용합니다.
#
# **다루는 내용**
# 1. 변수 — 값에 이름 붙이기
# 2. 자료형 — 정수·실수·문자열·불리언
# 3. 형 변환
# 4. 연산자 — 산술·비교·논리
# 5. 문자열 — 인덱싱·슬라이싱·메서드
# 6. 리스트
# 7. 튜플
# 8. 딕셔너리
# 9. 종합 연습
#
# > 📌 **✏️ 콜아웃으로 표시된 "연습문제"는 직접 입력하는 칸입니다.** 강사와 함께 한 줄씩 따라 입력해 봅니다.
#
# > **막히면?** 문제 사이사이의 **미니 챌린지**는 값을 바꿔 여러 번 실행하며 감을 익히는 칸입니다. 정답이 막히면 같은 폴더의 **`-정답` 노트북**(수업 후 공개)에서 같은 번호 셀을 참고하세요.

# %% [markdown]
# ## 0. 준비운동 — 셀과 출력
# `print()` 는 괄호 안의 값을 화면에 출력하는 명령입니다. `#` 뒤에 적은 글(주석)은 실행에 영향을 주지 않는 설명입니다.

# %%
print("파이썬 학습을 시작합니다.")   # # 뒤는 주석 (실행 안 됨)
print(1 + 1)                        # 계산 결과도 출력 가능

# %% [markdown]
# ## 1. 변수 — 값에 이름 붙이기
# 변수는 값에 이름을 붙여 저장해 두는 공간입니다. `=` 기호는 "오른쪽 값을 왼쪽 이름에 저장하라"는 의미로, 수학의 등호(같다)와는 다릅니다. 저장한 값은 이름으로 언제든 다시 꺼내 쓰거나 새로 바꿀 수 있습니다.

# %%
course = "인공지능 입문"   # 문자열 저장
year = 2026               # 정수 저장
print(course)
print(year)

year = year + 1           # 기존 값에 1을 더해 다시 저장
print(year)               # 2027

# %% [markdown]
# ### 변수 이름 규칙
# - 영문자·숫자·밑줄(`_`)로 짓고, **숫자로 시작할 수 없습니다.**
# - 대소문자를 구분합니다 (`score` 와 `Score` 는 다른 변수).
# - 의미가 드러나는 이름을 권장합니다 (`a` 보다 `student_count`).

# %%
student_count = 30
average_score = 87.5
print(student_count, average_score)   # 30 87.5

# %% [markdown]
# ## 2. 자료형 — 값의 종류
# 파이썬의 기본 자료형은 다음과 같습니다.
#
# | 자료형 | 설명 | 예 |
# |---|---|---|
# | `int` | 정수 | `1`, `-5`, `100` |
# | `float` | 실수 | `3.14`, `-0.5` |
# | `str` | 문자열 | `"AI"`, `'한경대'` |
# | `bool` | 불리언(참/거짓) | `True`, `False` |
#
# `type()` 으로 값의 자료형을 확인합니다.

# %%
a = 100          # int
b = 3.14         # float
c = "Hello"      # str
d = True         # bool

# type() 으로 자료형 확인
print(type(a), type(b), type(c), type(d))

# %% [markdown]
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 연습문제 1 변수 만들고 자료형 보기</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; 이름을 <code>name</code>, 나이를 <code>age</code>, 키(실수)를 <code>height</code> 에 저장하고 값과 자료형을 출력하세요.<br>
# <b>힌트</b> &nbsp; 빈칸(<code>____</code>)에 알맞은 값을 넣으세요 · 자료형은 <code>type(변수)</code> 로 확인<br>
# <b>예상</b> &nbsp; 값과 <code>&lt;class 'str'&gt;</code>·<code>'int'</code>·<code>'float'</code>
# </div>
# </div>

# %%
# ✏️ 연습문제 1 — 빈칸(____)을 채워 보세요
name = ____    # 본인 이름 (문자열)
age = ____     # 나이 (정수)
height = ____  # 키 (실수)

print(name, type(name))
print(age, type(age))
print(height, type(height))

# %% [markdown]
# ## 3. 형 변환 — 자료형 바꾸기
# 자료형은 서로 바꿀 수 있습니다. `int()` 정수로, `float()` 실수로, `str()` 문자열로 변환합니다. 특히 화면 입력값은 항상 문자열이므로 계산하려면 숫자로 바꿔야 합니다.

# %%
num_str = "25"           # 문자열
print(num_str + "년")     # 문자열 이어붙이기 → 25년

num = int(num_str)       # 정수로 변환
print(num + 5)           # 숫자 계산 → 30

print(str(num) + "살")    # 다시 문자열로 → 25살

# %% [markdown]
# ### 참고: 사용자 입력 받기
# `input()` 은 사용자가 입력한 값을 **문자열로** 돌려줍니다. 숫자로 쓰려면 `int()`·`float()` 로 변환합니다. Colab에서 실행하면 입력창이 나타납니다.

# %%
height_str = input("키를 입력하세요(cm): ")
height = float(height_str)
print(f"입력한 키는 {height}cm 입니다.")

# %% [markdown]
# ## 4. 연산자
# ### 4-1) 산술 연산자

# %%
a = 17
b = 5
print("덧셈:", a + b)
print("뺄셈:", a - b)
print("곱셈:", a * b)
print("나눗셈:", a / b)
print("몫:", a // b)       # 소수점 버림
print("나머지:", a % b)
print("거듭제곱:", a ** b)

# %% [markdown]
# <div style="border:1px dashed #C7A98F;border-radius:10px;background:#FCF7F0;padding:14px 18px;margin:10px 0;">
# <div style="font-size:15px;font-weight:700;color:#8A5A3C;margin-bottom:6px;">미니 챌린지 · 값을 바꿔가며 // 와 % 예측하기</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14px;">
# <code>a</code>, <code>b</code> 값을 바꿔 <b>세 번</b> 실행하고, 몫(<code>//</code>)·나머지(<code>%</code>)를 <b>먼저 예측한 뒤</b> 확인하세요.<br>① <code>a=20, b=6</code> &nbsp; ② <code>a=7, b=7</code> &nbsp; ③ <code>a=5, b=8</code><br><b>관찰</b> &nbsp; ③처럼 작은 수 ÷ 큰 수면 몫은 <code>0</code>, 나머지는 <code>a</code> 그대로가 됩니다.
# </div></div>

# %%
a = 20
b = 6
print("몫:", a // b, " 나머지:", a % b)   # ① 예상: 몫 3, 나머지 2
# ② a=7,b=7  ③ a=5,b=8 로 바꿔 다시 실행해 보세요

# %% [markdown]
# ### 4-2) 비교 연산자
# 비교의 결과는 항상 `True`/`False` 입니다. `==` 는 '같다', `=` 는 '저장'으로 서로 다릅니다.

# %%
x = 10
y = 7
print(x > y)
print(x == y)   # == 는 '같다'
print(x != y)   # != 는 '다르다'
print(x >= 10)

# %% [markdown]
# ### 4-3) 논리 연산자
# `and`(둘 다 참), `or`(하나라도 참), `not`(반대).

# %%
age = 22
has_id = True
print(age >= 19 and has_id)   # 둘 다 참
print(age < 19 or has_id)     # 하나라도 참
print(not has_id)             # 반대

# %% [markdown]
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 연습문제 2 예산과 가격 비교</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; <code>price = 12000</code>, <code>budget = 10000</code> 을 만들고 예산이 가격 이상인지 출력하세요.<br>
# <b>힌트</b> &nbsp; 빈칸(<code>____</code>)을 채우세요 · '가격 이상'은 크거나 같음을 뜻하는 비교 연산자입니다<br>
# <b>예상</b> &nbsp; <code>False</code> (예산이 부족)
# </div>
# </div>

# %%
# ✏️ 연습문제 2 — 빈칸(____)을 채워 보세요
price = 12000
budget = 10000
print(budget ____ price)

# 예상: False

# %% [markdown]
# ## 5. 문자열 다루기
# ### 5-1) 이어붙이기와 f-string
# `+` 로 문자열을 잇고, `*` 로 반복합니다. 값을 글자 사이에 끼워 넣을 땐 f-string(따옴표 앞 `f`, `{ }` 안에 값)이 편리합니다.

# %%
first = "한경"
last = "국립대"
print(first + last)     # 이어붙이기 → 한경국립대
print(first * 3)        # 반복 → 한경한경한경

name = "지민"
score = 92
print(f"{name}님의 점수는 {score}점입니다.")   # f-string

# %% [markdown]
# ### 5-2) 인덱싱과 슬라이싱
# 문자열의 각 글자에는 0번부터 번호가 붙습니다. `[시작:끝]` 으로 일부를 잘라냅니다(끝 번호는 포함하지 않음). 음수 인덱스는 뒤에서부터 셉니다.

# %%
text = "Artificial"
print(text[0])     # 0번째 → A
print(text[-1])    # 마지막 → l
print(text[0:4])   # 0~3번 → Arti
print(text[:4])    # Arti
print(text[4:])    # ficial
print(len(text))   # 글자 수 → 10

# %% [markdown]
# <div style="border:1px dashed #C7A98F;border-radius:10px;background:#FCF7F0;padding:14px 18px;margin:10px 0;">
# <div style="font-size:15px;font-weight:700;color:#8A5A3C;margin-bottom:6px;">미니 챌린지 · 슬라이싱 여러 방법 실험</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14px;">
# <code>text = "Artificial"</code> 를 그대로 두고 아래를 각각 실행해 결과를 확인하세요.<br>① <code>text[2:6]</code> &nbsp; ② <code>text[-4:]</code> &nbsp; ③ <code>text[::2]</code> &nbsp; ④ <code>text[::-1]</code><br><b>예상</b> &nbsp; ① <code>tifi</code> &nbsp; ② <code>cial</code> &nbsp; ③ <code>Atfca</code> &nbsp; ④ <code>laicifitrA</code>
# </div></div>

# %%
text = "Artificial"
print(text[2:6])    # ① 예상: tifi
print(text[-4:])    # ② 예상: cial
print(text[::2])    # ③ 예상: Atfca
print(text[::-1])   # ④ 예상: laicifitrA

# %% [markdown]
# ### 5-3) 문자열 메서드
# 메서드는 값에 `.` 을 붙여 호출하는 기능입니다. 문자열에는 자주 쓰는 메서드가 많습니다.

# %%
s = "  Hello, AI World  "
print(s.strip())              # 양옆 공백 제거
print(s.upper())              # 대문자
print(s.lower())              # 소문자
print(s.replace("AI", "ML"))  # 일부 바꾸기
print("a,b,c".split(","))     # 쪼개기 → ['a','b','c']

# %% [markdown]
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 연습문제 3 이메일 나누기 <span style="font-size:12px;color:#A8472A;background:#F0DCCF;padding:1px 8px;border-radius:10px;margin-left:6px;">직접 작성</span></div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; <code>email = "student@hknu.ac.kr"</code> 을 <code>@</code> 기준으로 나눠 아이디와 도메인을 각각 출력하세요.<br>
# <b>힌트</b> &nbsp; 문자열을 특정 문자 기준으로 나누는 메서드(<code>split</code>) · 결과 리스트를 두 변수로 나눠 받기<br>
# <b>예상</b> &nbsp; <code>student</code> / <code>hknu.ac.kr</code>
# </div>
# </div>

# %%
# ✏️ 직접 작성 — 이메일을 @ 기준으로 나눠 아이디·도메인 출력
email = "student@hknu.ac.kr"

# 여기에 코드를 작성하세요


# 예상: student / hknu.ac.kr

# %% [markdown]
# ## 6. 리스트 — 여러 값을 순서대로
# 대괄호 `[ ]` 로 만들며, 0번부터 번호(인덱스)로 접근합니다. 문자열처럼 슬라이싱도 됩니다.

# %%
scores = [88, 92, 79, 95, 60]
print(scores[0])      # 첫 항목 → 88
print(scores[-1])     # 마지막 → 60
print(scores[1:3])    # 슬라이싱 → [92, 79]
print(len(scores))    # 개수 → 5
print(sum(scores))    # 합 → 414
print(max(scores), min(scores))   # 95 60

# %% [markdown]
# ### 6-1) 리스트 메서드

# %%
fruits = ["사과", "바나나", "체리"]
fruits.append("오렌지")      # 맨 뒤에 추가
fruits.insert(0, "딸기")     # 0번 위치에 삽입
fruits.remove("바나나")      # 값으로 삭제
print(fruits)

fruits.sort()               # 가나다순 정렬
print(fruits)

# %% [markdown]
# <div style="border:1px dashed #C7A98F;border-radius:10px;background:#FCF7F0;padding:14px 18px;margin:10px 0;">
# <div style="font-size:15px;font-weight:700;color:#8A5A3C;margin-bottom:6px;">미니 챌린지 · 리스트 메서드 이어서 실험</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14px;">
# 위 <code>fruits</code> 로 아래를 <b>순서대로</b> 실행하며 리스트가 어떻게 바뀌는지 보세요.<br>① <code>fruits.append("포도")</code> 후 <code>print(fruits)</code><br>② <code>fruits.reverse()</code> 후 <code>print(fruits)</code><br>③ <code>len(fruits)</code> &nbsp; ④ <code>"체리" in fruits</code><br><b>관찰</b> &nbsp; 메서드는 리스트를 <b>직접</b> 바꿉니다 — 다시 대입할 필요가 없습니다.
# </div></div>

# %%
fruits.append("포도")
print(fruits)
fruits.reverse()
print(fruits)
print(len(fruits), "체리" in fruits)

# %% [markdown]
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 연습문제 4 리스트 정렬·합계·평균 <span style="font-size:12px;color:#A8472A;background:#F0DCCF;padding:1px 8px;border-radius:10px;margin-left:6px;">직접 작성</span></div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; <code>nums = [5, 3, 9, 1, 7]</code> 의 정렬 결과·합계·평균을 출력하세요.<br>
# <b>힌트</b> &nbsp; 리스트의 정렬 메서드 · 합계는 <code>sum</code> · 평균은 합계 ÷ 개수(<code>len</code>)<br>
# <b>예상</b> &nbsp; <code>[1, 3, 5, 7, 9]</code> · 25 · 5.0
# </div>
# </div>

# %%
# ✏️ 직접 작성 — nums 의 정렬 결과·합계·평균 출력
nums = [5, 3, 9, 1, 7]

# 여기에 코드를 작성하세요


# 예상: [1, 3, 5, 7, 9] · 25 · 5.0

# %% [markdown]
# ## 7. 튜플 — 바뀌지 않는 묶음
# 소괄호 `( )` 로 만들며, 한 번 만들면 **수정할 수 없습니다**. 좌표처럼 고정된 값에 적합합니다.

# %%
point = (37.5, 127.0)   # (위도, 경도)
print(point[0])         # 37.5

# point[0] = 0          # 튜플은 수정 불가 → 오류

lat, lon = point        # 언패킹
print(lat, lon)

# %% [markdown]
# ## 8. 딕셔너리 — 이름표(키)로 값 관리
# 중괄호 `{ }` 안에 `키: 값` 형태로 저장하고, 키로 값을 꺼냅니다. 리스트가 번호로 접근한다면 딕셔너리는 이름으로 접근합니다.

# %%
student = {"name": "지민", "age": 22, "major": "AI"}
print(student["name"])     # 키로 값 꺼내기 → 지민
student["grade"] = 3        # 새 항목 추가
student["age"] = 23         # 기존 값 수정
print(student)

# %% [markdown]
# ### 8-1) 키·값 다루기

# %%
print(student.keys())                     # 키 목록
print(student.values())                   # 값 목록
print(student.get("major"))               # AI
print(student.get("phone", "정보 없음"))   # 없는 키는 기본값 반환

# %% [markdown]
# <div style="border:1px dashed #C7A98F;border-radius:10px;background:#FCF7F0;padding:14px 18px;margin:10px 0;">
# <div style="font-size:15px;font-weight:700;color:#8A5A3C;margin-bottom:6px;">미니 챌린지 · 있는 키 · 없는 키 접근 비교</div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14px;">
# <code>student</code> 로 아래를 실행해 <code>[]</code> 와 <code>.get()</code> 의 차이를 확인하세요.<br>① <code>student["major"]</code> &nbsp; ② <code>student.get("phone")</code> (없는 키) &nbsp; ③ <code>student.get("phone", "미입력")</code> &nbsp; ④ <code>"name" in student</code><br><b>관찰</b> &nbsp; 없는 키를 <code>[]</code>로 꺼내면 <b>오류</b>, <code>.get()</code>은 <code>None</code>(또는 기본값)을 돌려줍니다.
# </div></div>

# %%
print(student["major"])              # ① AI
print(student.get("phone"))          # ② None (오류 아님)
print(student.get("phone", "미입력"))   # ③ 미입력
print("name" in student)             # ④ True

# %% [markdown]
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 연습문제 5 나를 담은 딕셔너리 <span style="font-size:12px;color:#A8472A;background:#F0DCCF;padding:1px 8px;border-radius:10px;margin-left:6px;">직접 작성</span></div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; 본인을 표현하는 딕셔너리 <code>me</code> 를 키 3개 이상으로 만들고, 키 하나를 추가한 뒤 전체를 출력하세요.<br>
# <b>힌트</b> &nbsp; 중괄호 <code>{키: 값}</code> 형태로 만들고, 새 항목은 <code>me[새키] = 값</code> 으로 추가<br>
# <b>예상</b> &nbsp; 키 4개 이상이 담긴 딕셔너리
# </div>
# </div>

# %%
# ✏️ 직접 작성 — 나를 표현하는 딕셔너리 me 만들고 키 추가 후 출력

# 여기에 코드를 작성하세요


# 예상: 키 4개 이상이 담긴 딕셔너리 출력

# %% [markdown]
# ## 9. 종합 연습
# 지금까지 배운 변수·자료형·리스트·딕셔너리를 함께 사용해 봅니다.
#
# <div style="border:1px solid #E7DCC6;border-left:6px solid #C15F3C;border-radius:10px;background:#FBF4EA;padding:16px 20px;margin:12px 0;">
# <div style="font-size:16px;font-weight:700;color:#A8472A;margin-bottom:8px;">✏️ 종합문제 학생 점수 다루기 <span style="font-size:12px;color:#A8472A;background:#F0DCCF;padding:1px 8px;border-radius:10px;margin-left:6px;">종합</span></div>
# <div style="color:#3D3A33;line-height:1.8;font-size:14.5px;">
# <b>문제</b> &nbsp; <code>students</code>(학생 3명)의 이름·점수를 한 줄씩 출력하고, 세 점수의 평균과 <b>가장 점수가 높은 학생의 이름</b>을 출력하세요.<br>
# <b>힌트</b> &nbsp; 값 꺼내기 <code>students[0]["name"]</code> · 세 점수를 리스트로 모으면 <code>max</code> 로 최고점을, 리스트의 <code>.index()</code> 로 그 위치를 찾을 수 있습니다 · 반복문은 다음 노트북에서 배웁니다.<br>
# <b>예상</b> &nbsp; 이름: 점수 3줄 + 평균 약 86.3 + 최고점 학생: 현우
# </div>
# </div>

# %%
# ✏️ 직접 작성 — 이름:점수 3줄 출력 + 평균 + 최고점 학생 이름
students = [
    {"name": "지민", "score": 88},
    {"name": "현우", "score": 92},
    {"name": "수아", "score": 79},
]

# 여기에 코드를 작성하세요
# ① 세 학생의 "이름: 점수" 를 한 줄씩 출력
# ② 세 점수의 평균 출력
# ③ (추가) 가장 점수가 높은 학생의 이름 출력


# 예상: 3줄 출력 · 평균 약 86.3 · 최고점 학생: 현우

# %% [markdown]
# ## 정리
# - **변수**는 `=` 로 값에 이름을 붙이는 것이며, 기본 자료형은 `int`·`float`·`str`·`bool` 입니다.
# - **문자열**은 인덱싱·슬라이싱·메서드로 자유롭게 가공할 수 있습니다.
# - **리스트**(`[ ]`, 순서) · **튜플**(`( )`, 고정) · **딕셔너리**(`{ }`, 키-값)로 여러 값을 묶어 관리합니다.
#
# 다음 노트북 **s3-02 (제어 흐름과 함수)** 에서는 조건에 따라 분기하는 `if`, 반복 작업을 처리하는 `for`·`while`, 그리고 기능을 묶는 함수를 다룹니다.

# %% [markdown]
# ## 스스로 점검
# 아래를 막힘 없이 할 수 있으면 이 노트북은 성공입니다. 하나라도 헷갈리면 위로 올라가 해당 셀을 다시 실행해 보세요.
#
# - 변수에 값을 저장하고 `type()` 으로 자료형을 확인할 수 있다
# - 문자열을 슬라이싱하고 `split()` 으로 나눌 수 있다
# - 리스트에 값을 추가·정렬하고 합계·평균을 구할 수 있다
# - 딕셔너리에서 키로 값을 꺼내고 새 키를 추가할 수 있다
#
# > **막히면?** 같은 폴더의 **`-정답` 노트북**(수업 후 공개)에서 같은 번호 셀을 확인하세요.

# %% [markdown]
# # 1차시 · 첫 파이썬 실습 (환경 확인)
#
# 설치 없이 **Google Colab**에서 바로 실행합니다. 각 코드 셀을 선택하고 **▶ (Shift+Enter)** 로 실행해 보세요.
#
# > 오늘은 "환경이 잘 돌아가는지" 확인하는 게 목표예요. 본격적인 파이썬은 2차시에서 배웁니다.

# %% [markdown]
# ## 1. 첫 출력
# 화면에 글자를 찍어 봅니다.

# %%
print("Hello, AI!")

# %% [markdown]
# ## 2. 변수와 계산
# 값을 이름에 담고, 계산해 봅니다.

# %%
name = "AI"
print(name, "와 함께 시작합니다")

a = 3
b = 4
print("a + b =", a + b)

# %% [markdown]
# ## 3. 반복
# 같은 일을 여러 번 자동으로 해 봅니다.

# %%
for i in range(3):
    print("실행", i)

# %% [markdown]
# ## 4. 확인
# 아래가 오류 없이 실행되면 실습 환경 준비 완료! 🎉

# %%
import sys
print("파이썬 버전:", sys.version.split()[0])
print("환경 준비 완료")
